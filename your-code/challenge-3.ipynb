# %% [markdown]
# # Challenge 3: Hidden Cold Joke
#
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.
#
#
# After you find out the secrete files:
#
# Sort the filenames ascendingly.
#
# Read the content of each secret files into an array of strings.
#
# Concatenate the strings in the array separating each two with a whitespace.
#
# Print out the joke.

# %% [markdown]
# ⚠️ **Remember to limit your output before submission**.

# %%
# Your code

# %%
# Example: print(variable[:10])

# %%
import json
import requests

# %%
with open('../password.txt', 'r') as file:
    pass_=file.read()

# %%
HEADER={'Authorization': 'token ' + pass_}

# %% [markdown]
# **VERSIÓN 1 (no funciona jeje)**

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents'

response = requests.get(url, headers=HEADER)

response
# Out:
# <Response [200]>

# %%
response.json()

# %%
lst = []
contador = 0
for e in response.json():
    lst.append(response.json()[contador]['name'])
    contador+=1
    
lst
# Out:
# ['.gitignore',
#  '15024',
#  '15534',
#  '17020',
#  '30351',
#  '40303',
#  '44639',
#  '45525',
#  '47222',
#  '47830',
#  '49418',
#  '50896',
#  '55417',
#  '55685',
#  '60224',
#  '64880',
#  '66032',
#  '68848',
#  '70751',
#  '70985',
#  '88596',
#  '89046',
#  '89338',
#  '91701',
#  '97881',
#  '98750']

# %%
lst = lst[1:]

# %%
lst
# Out:
# ['15024',
#  '15534',
#  '17020',
#  '30351',
#  '40303',
#  '44639',
#  '45525',
#  '47222',
#  '47830',
#  '49418',
#  '50896',
#  '55417',
#  '55685',
#  '60224',
#  '64880',
#  '66032',
#  '68848',
#  '70751',
#  '70985',
#  '88596',
#  '89046',
#  '89338',
#  '91701',
#  '97881',
#  '98750']

# %%
lista_nombres = []


contador = 0

for folder in lst:
    url = f'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{folder}'
    nombre = requests.get(url, headers=HEADER)
    lista_nombres.append(nombre.json()[contador]['name'])
    

lista_nombres
# Out:
# ['.0006.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0003.scavengerhunt',
#  '3',
#  '28',
#  '.0004.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0002.scavengerhunt',
#  '64',
#  '.0013.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0001.scavengerhunt']

# %%
lista_nombres_clean = [e for e in lista_nombres if len(e) > 4]

lista_nombres_clean
# Out:
# ['.0006.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0023.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0001.scavengerhunt']

# %%
lista_nombres_clean.sort()

# %%
lista_nombres_clean
# Out:
# ['.0001.scavengerhunt',
#  '.0002.scavengerhunt',
#  '.0003.scavengerhunt',
#  '.0004.scavengerhunt',
#  '.0005.scavengerhunt',
#  '.0006.scavengerhunt',
#  '.0007.scavengerhunt',
#  '.0008.scavengerhunt',
#  '.0009.scavengerhunt',
#  '.0010.scavengerhunt',
#  '.0011.scavengerhunt',
#  '.0013.scavengerhunt',
#  '.0014.scavengerhunt',
#  '.0015.scavengerhunt',
#  '.0016.scavengerhunt',
#  '.0017.scavengerhunt',
#  '.0018.scavengerhunt',
#  '.0019.scavengerhunt',
#  '.0020.scavengerhunt',
#  '.0021.scavengerhunt',
#  '.0022.scavengerhunt',
#  '.0023.scavengerhunt']

# %%
url_contenido = 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/15024/.0006.scavengerhunt'

content = requests.get(url_contenido, headers=HEADER)

# %%
content
# Out:
# <Response [200]>

# %%
with open(contenido, 'r') as c:
    print(c.read())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/_n/g7dsgr5d6hs1plzfmyy449980000gn/T/ipykernel_3668/2909092906.py in <module>
# ----> 1 with open(contenido, 'r') as c:
#       2     print(c.read())
#
# TypeError: expected str, bytes or os.PathLike object, not dict

# %% [markdown]
# **VERSIÓN 2**

# %%
url = 'https://api.github.com/repos/ironhack-datalabs/scavenger/commits/9308ccc8a4c34c5e3a991ee815222a9691c32476'

response = requests.get(url, headers=HEADER)

response
# Out:
# <Response [200]>

# %%
response.json()['files']
# Out:
# [{'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'filename': '.gitignore',
#   'status': 'added',
#   'additions': 1,
#   'deletions': 0,
#   'changes': 1,
#   'blob_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/.gitignore',
#   'raw_url': 'https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/.gitignore',
#   'contents_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#   'patch': '@@ -0,0 +1 @@\n+.DS_Store'},
#  {'sha': '1c9064284a24b3486015eafdb391b141c27ada2b',
#   'filename': '15024/.0006.scavengerhunt',
#   'status': 'added',
#   'additions': 1,
#   'deletions': 0,
#   'changes': 1,
#   'blob_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024%2F.0006.scavengerhunt',
# ...

# %%
links = []
for e in range(len(response.json()['files'])):
    if (response.json()['files'][e]['raw_url']).endswith('scavengerhunt'):
        links.append(response.json()['files'][e]['raw_url'])
        
links[0:3]
# Out:
# ['https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/15024%2F.0006.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/15534%2F.0008.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/15534%2F.0012.scavengerhunt']

# %%
sort_links = sorted(links, key = lambda x: int(x[-16:-14]))

sort_links[:3]
# Out:
# ['https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/98750%2F.0001.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/88596%2F.0002.scavengerhunt',
#  'https://github.com/ironhack-datalabs/scavenger/raw/9308ccc8a4c34c5e3a991ee815222a9691c32476/60224%2F.0003.scavengerhunt']

# %%
frase = [(requests.get(e).text) for e in sort_links]

frase
# Out:
# ['In\n',
#  'data\n',
#  'science,\n',
#  '80\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'spent\n',
#  'is\n',
#  'preparing\n',
#  'data,\n',
#  '20\n',
#  'percent\n',
#  'of\n',
#  'time\n',
#  'is\n',
#  'spent\n',
#  'complaining\n',
#  'about\n',
#  'the\n',
#  'need\n',
#  'to\n',
#  'prepare\n',
#  'data.\n']

# %%
frase = ' '.join(frase)

# %%
frase
# Out:
# 'In\n data\n science,\n 80\n percent\n of\n time\n spent\n is\n preparing\n data,\n 20\n percent\n of\n time\n is\n spent\n complaining\n about\n the\n need\n to\n prepare\n data.\n'

# %%
frase = frase.replace('\n', '')

# %%
frase
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'
